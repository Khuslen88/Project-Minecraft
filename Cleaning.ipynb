# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('mcitems.csv')

# %%
df.head()
# Out:
#   Unnamed: 0   Unnamed: 1         Unnamed: 2     Unnamed: 3 Unnamed: 4  \
# 0       Item    Item Name  Resource Location  Creative Only    OP Only
# 1        NaN          NaN                NaN            NaN        NaN
# 2       1746          NaN                NaN       188/1746    42/1746
# 3        NaN          Air                air           TRUE       TRUE
# 4        NaN  Cobblestone        cobblestone          FALSE      FALSE
#
#       Unnamed: 5 Unnamed: 6 Unnamed: 7                         Unnamed: 8  \
# 0  Commands Only  Max Stack  Renewable  Infinitely Automatically Farmable
# 1            NaN        NaN        NaN                         Any Method
# 2        13/1746        NaN  1397/1746                          1277/1746
# 3           TRUE        NaN      FALSE                              FALSE
# 4          FALSE         64       TRUE                               TRUE
#
#                      Unnamed: 9  ...    Unnamed: 42              Unnamed: 43  \
# ...

# %%
# # Set the first and second rows as multi-level columns
# df.columns = pd.MultiIndex.from_arrays(df.iloc[:1].values)
# # Drop the first two rows as they're now part of the column headers
# df = df.iloc[1:].reset_index(drop=True)
# df

# %%
# Replace column names with the values from the 0th row
df.columns = df.iloc[0]
# Take all rows except 0th row
df = df[1:]
# Reset the index
df.reset_index(drop=True, inplace=True)
# Display the updated DataFrame
df
# Out:
# 0     Item                   Item Name           Resource Location  \
# 0      NaN                         NaN                         NaN
# 1     1746                         NaN                         NaN
# 2      NaN                         Air                         air
# 3      NaN                 Cobblestone                 cobblestone
# 4      NaN            Cobblestone Slab            cobblestone_slab
# ...    ...                         ...                         ...
# 1743   NaN            Zoglin Spawn Egg            zoglin_spawn_egg
# 1744   NaN            Zombie Spawn Egg            zombie_spawn_egg
# 1745   NaN      Zombie Horse Spawn Egg      zombie_horse_spawn_egg
# 1746   NaN   Zombie Villager Spawn Egg   zombie_villager_spawn_egg
# 1747   NaN  Zombified Piglin Spawn Egg  zombified_piglin_spawn_egg
#
# 0    Creative Only  OP Only Commands Only Max Stack  Renewable  \
# 0              NaN      NaN           NaN       NaN        NaN
# ...

# %%
df.isnull().sum()
# Out:
# 0
# Item                                  1747
# Item Name                                2
# Resource Location                        2
# Creative Only                            1
# OP Only                                  1
# Commands Only                            1
# Max Stack                                3
# Renewable                                1
# Infinitely Automatically Farmable        0
# NaN                                      0
# Has a Direct Block Form                  1
# Has a Direct Entity Form                 1
# Durability                            1680
# Fuel Time                             1496
# XP From Cooking                       1624
# Enchantability                        1688
# Mining Speed Multiplier                  2
# Mining Level                             2
# Melee Attack Damage                      2
# Melee Attack Speed                       2
# Defence                               1723
# Toughness                             1723
# ...

# %%
# Drop unnecessary columns
df = df.drop(['Creative Only','OP Only','Commands Only','Resource Location','Wearable','Edible','Fire Resistant','Blast Resistant','Can Repair Gear','Has Data Components','Seperate Item Icon','Obtainable From Cooking','Sold by Wandering Traders','Sold by Villagers','Sold to Villagers','Can be Used in an Enchanting Table','Unique Dispenser Interaction','Lures Entites When Held','Can be Eaten with Full Hunger','Mining Level','Melee Attack Damage','Melee Attack Speed','Mining Speed Multiplier','Max Stack','Renewable','Infinitely Automatically Farmable','Has a Direct Entity Form','Has a Direct Block Form','Item','Durability','Fuel Time','XP From Cooking','Enchantability','Defence','Toughness','Knockback Resistance','Hunger Filled','Saturation Filled'], axis=1)

# %%
# df.drop(df.columns[1], axis=1).drop(df.columns[-1], axis=1)

# %%
df
# Out:
# 0                      Item Name                           NaN  \
# 0                            NaN  Player Interactions Required
# 1                            NaN                      497/1746
# 2                            Air                         FALSE
# 3                    Cobblestone                         FALSE
# 4               Cobblestone Slab                         FALSE
# ...                          ...                           ...
# 1743            Zoglin Spawn Egg                         FALSE
# 1744            Zombie Spawn Egg                         FALSE
# 1745      Zombie Horse Spawn Egg                         FALSE
# 1746   Zombie Villager Spawn Egg                         FALSE
# 1747  Zombified Piglin Spawn Egg                         FALSE
#
# 0    Can Have Enchantments Used In Crafting Obtainable From Crafting  \
# 0                      NaN              NaN                      NaN
# ...

# %%
df.columns = pd.MultiIndex.from_tuples([
    ("Item Properties", "Item Name"), 
    ("Item Properties", "Can Have Enchantments"), 
    ("Item Properties", "Used In Crafting"), 
    ("Item Properties", "Obtainable From Crafting"), 
    ("Item Properties", "Has A Unique \"Use\" Function"), 
    ("Can Be Cooked", "Furnace"), 
    ("Can Be Cooked", "Smoker/Campfire"), 
    ("Can Be Cooked", "Blast Furnace"), 
    ("Rarity", "Common"), 
    ("Rarity", "Uncommon"), 
    ("Rarity", "Rare"), 
    ("Rarity", "Epic"), 
    ("Other", None),
    ("Other", None)
])

df = pd.DataFrame(df[2:], columns = df.columns)
df
# Out:
#                  Item Properties                                         \
#                        Item Name Can Have Enchantments Used In Crafting
# 2                            Air                 FALSE            FALSE
# 3                    Cobblestone                 FALSE            FALSE
# 4               Cobblestone Slab                 FALSE            FALSE
# 5             Cobblestone Stairs                 FALSE            FALSE
# 6               Cobblestone Wall                 FALSE            FALSE
# ...                          ...                   ...              ...
# 1743            Zoglin Spawn Egg                 FALSE            FALSE
# 1744            Zombie Spawn Egg                 FALSE            FALSE
# 1745      Zombie Horse Spawn Egg                 FALSE            FALSE
# 1746   Zombie Villager Spawn Egg                 FALSE            FALSE
# 1747  Zombified Piglin Spawn Egg                 FALSE            FALSE
#
# ...

# %%
df = df.drop("Other", axis=1)
df
# Out:
#                  Item Properties                                         \
#                        Item Name Can Have Enchantments Used In Crafting
# 2                            Air                 FALSE            FALSE
# 3                    Cobblestone                 FALSE            FALSE
# 4               Cobblestone Slab                 FALSE            FALSE
# 5             Cobblestone Stairs                 FALSE            FALSE
# 6               Cobblestone Wall                 FALSE            FALSE
# ...                          ...                   ...              ...
# 1743            Zoglin Spawn Egg                 FALSE            FALSE
# 1744            Zombie Spawn Egg                 FALSE            FALSE
# 1745      Zombie Horse Spawn Egg                 FALSE            FALSE
# 1746   Zombie Villager Spawn Egg                 FALSE            FALSE
# 1747  Zombified Piglin Spawn Egg                 FALSE            FALSE
#
# ...

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.to_csv('mc_items.csv', index=False)
